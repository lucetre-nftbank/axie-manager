# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import json
import requests

# %%
class AxieCriterion:
    def __init__(self, query):
        url, params = query.split('?')
        classes = []
        parts = []
        speeds = []
        hps = []
        skills = []
        morales = []
        for param in params.split('&'):
            attr, val = param.split('=')
            if attr == 'class':
                classes.append(val)
            elif attr == 'part':
                parts.append(val)
            elif attr == 'speed':
                speeds.append(int(val))
            elif attr == 'hp':
                hps.append(int(val))
            elif attr == 'skill':
                skills.append(int(val))
            elif attr == 'morale':
                morales.append(int(val))
                
        speeds = sorted(speeds)
        hps = sorted(hps)
        skills = sorted(skills)
        morales = sorted(morales)
        
        self.body = {
            "operationName": "GetAxieBriefList",
            "query": "query GetAxieBriefList($auctionType: AuctionType, $criteria: AxieSearchCriteria, $from: Int, $sort: SortBy, $size: Int, $owner: String, $filterStuckAuctions: Boolean) {\n  axies(\n    auctionType: $auctionType\n    criteria: $criteria\n    from: $from\n    sort: $sort\n    size: $size\n    owner: $owner\n    filterStuckAuctions: $filterStuckAuctions\n  ) {\n    total\n    results {\n      ...AxieBrief\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment AxieBrief on Axie {\n  id\n  name\n  stage\n  class\n  breedCount\n  image\n  title\n  battleInfo {\n    banned\n    __typename\n  }\n  auction {\n    currentPrice\n    currentPriceUSD\n    __typename\n  }\n  parts {\n    id\n    name\n    class\n    type\n    specialGenes\n    __typename\n  }\n  __typename\n}\n",
            "variables": {
                "auctionType": "Sale",
                "criteria": {
                    "bodyShapes": None,
                    "breedable": None,
                    "breedCount": None,
                    "classes": classes,
                    "hp": [],
                    "morale": [],
                    "numJapan": None,
                    "numMystic": None,
                    "numXmas": None,
                    "parts": parts,
                    "pureness": None,
                    "purity": [],
                    "region": None,
                    "skill": [],
                    "speed": [],
                    "stages": None,
                    "title": None
                },
                "filterStuckAuctions": True,
                "from": 0,
                "owner": None,
                "size": 24,
                "sort": "PriceAsc"
            }
        }
        if len(speeds) == 2:
            self.body["variables"]["criteria"]["speed"] = speeds
        if len(hps) == 2:
            self.body["variables"]["criteria"]["hp"] = hps
        if len(skills) == 2:
            self.body["variables"]["criteria"]["skill"] = skills
        if len(morales) == 2:
            self.body["variables"]["criteria"]["morale"] = morales
        
    def marketplace(self):
        r = requests.post("https://graphql-gateway.axieinfinity.com/graphql", json=self.body)
        data = json.loads(r.text)['data']['axies']
        return data
    
query = 'https://marketplace.axieinfinity.com/axie/?class=Bird&speed=61&speed=61&auctionTypes=Sale'
ac = AxieCriterion(query)
ac.marketplace()
# Out:
# {'total': 23561,
#  'results': [{'id': '4814027',
#    'name': 'Sponge Bird',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 0,
#    'image': 'https://assets.axieinfinity.com/axies/4814027/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '17850000000000000',
#     'currentPriceUSD': '44.83',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-pink-cheek',
#      'name': 'Pink Cheek',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-sponge',
#      'name': 'Sponge',
#      'class': 'Aquatic',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-eggshell',
#      'name': 'Eggshell',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-the-last-one',
#      'name': 'The Last One',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '2609290',
#    'name': 'Axie #2609290',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 2,
#    'image': 'https://assets.axieinfinity.com/axies/2609290/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '18000000000000000',
#     'currentPriceUSD': '45.20',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-early-bird',
#      'name': 'Early Bird',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-cupid',
#      'name': 'Cupid',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-doubletalk',
#      'name': 'Doubletalk',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-oranda',
#      'name': 'Oranda',
#      'class': 'Aquatic',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-nimo',
#      'name': 'Nimo',
#      'class': 'Aquatic',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '2120277',
#    'name': 'Axie #2120277',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 3,
#    'image': 'https://assets.axieinfinity.com/axies/2120277/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '18910961197916669',
#     'currentPriceUSD': '47.49',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-owl',
#      'name': 'Owl',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-cupid',
#      'name': 'Cupid',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-anemone',
#      'name': 'Anemone',
#      'class': 'Aquatic',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-granmas-fan',
#      'name': "Granma's Fan",
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '3055437',
#    'name': 'Fishy',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 2,
#    'image': 'https://assets.axieinfinity.com/axies/3055437/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19000000000000000',
#     'currentPriceUSD': '47.72',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-pigeon-post',
#      'name': 'Pigeon Post',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-catfish',
#      'name': 'Catfish',
#      'class': 'Aquatic',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-eggshell',
#      'name': 'Eggshell',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-cloud',
#      'name': 'Cloud',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '543910',
#    'name': 'Axie #543910',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 4,
#    'image': 'https://assets.axieinfinity.com/axies/543910/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19000000000000000',
#     'currentPriceUSD': '47.72',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-early-bird',
#      'name': 'Early Bird',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-cupid',
#      'name': 'Cupid',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-cuckoo',
#      'name': 'Cuckoo',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-feather-fan',
#      'name': 'Feather Fan',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '1609240',
#    'name': 'High speed 61',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 1,
#    'image': 'https://assets.axieinfinity.com/axies/1609240/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19000000000000000',
#     'currentPriceUSD': '47.72',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-gero',
#      'name': 'Gero',
#      'class': 'Aquatic',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-cupid',
#      'name': 'Cupid',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-risky-fish',
#      'name': 'Risky Fish',
#      'class': 'Aquatic',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-eggshell',
#      'name': 'Eggshell',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-the-last-one',
#      'name': 'The Last One',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '6014471',
#    'name': 'Speed + Back Door + Heal',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 1,
#    'image': 'https://assets.axieinfinity.com/axies/6014471/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19095442708333330',
#     'currentPriceUSD': '47.95',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-robin',
#      'name': 'Robin',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-pink-cheek',
#      'name': 'Pink Cheek',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-anemone',
#      'name': 'Anemone',
#      'class': 'Aquatic',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-kestrel',
#      'name': 'Kestrel',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-granmas-fan',
#      'name': "Granma's Fan",
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '10869242',
#    'name': 'LO B13-$',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 0,
#    'image': 'https://assets.axieinfinity.com/axies/10869242/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19115416666666666',
#     'currentPriceUSD': '48.00',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-early-bird',
#      'name': 'Early Bird',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-pigeon-post',
#      'name': 'Pigeon Post',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-cuckoo',
#      'name': 'Cuckoo',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-post-fight',
#      'name': 'Post Fight',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '1596487',
#    'name': 'Bird Speed',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 3,
#    'image': 'https://assets.axieinfinity.com/axies/1596487/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19179799578059067',
#     'currentPriceUSD': '48.17',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-goldfish',
#      'name': 'Goldfish',
#      'class': 'Aquatic',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-kestrel',
#      'name': 'Kestrel',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-granmas-fan',
#      'name': "Granma's Fan",
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '2522320',
#    'name': 'A12',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 3,
#    'image': 'https://assets.axieinfinity.com/axies/2522320/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19396604938271604',
#     'currentPriceUSD': '48.71',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-early-bird',
#      'name': 'Early Bird',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-raven',
#      'name': 'Raven',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-hungry-bird',
#      'name': 'Hungry Bird',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-kestrel',
#      'name': 'Kestrel',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-feather-fan',
#      'name': 'Feather Fan',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '1685949',
#    'name': 'Axie #1685949',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 2,
#    'image': 'https://assets.axieinfinity.com/axies/1685949/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19562175925925929',
#     'currentPriceUSD': '49.13',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-early-bird',
#      'name': 'Early Bird',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-sponge',
#      'name': 'Sponge',
#      'class': 'Aquatic',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-kestrel',
#      'name': 'Kestrel',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-granmas-fan',
#      'name': "Granma's Fan",
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '4336135',
#    'name': 'C2 Bird Axie #4336135',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 4,
#    'image': 'https://assets.axieinfinity.com/axies/4336135/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19621248919753086',
#     'currentPriceUSD': '49.28',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-tri-feather',
#      'name': 'Tri Feather',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-feather-spear',
#      'name': 'Feather Spear',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-feather-fan',
#      'name': 'Feather Fan',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '5844139',
#    'name': 'Reptile killer',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 3,
#    'image': 'https://assets.axieinfinity.com/axies/5844139/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '19900000000000000',
#     'currentPriceUSD': '49.98',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-pink-cheek',
#      'name': 'Pink Cheek',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-raven',
#      'name': 'Raven',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-doubletalk',
#      'name': 'Doubletalk',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-oranda',
#      'name': 'Oranda',
#      'class': 'Aquatic',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-post-fight',
#      'name': 'Post Fight',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '3288142',
#    'name': 'Axie #3288142',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 2,
#    'image': 'https://assets.axieinfinity.com/axies/3288142/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-owl',
#      'name': 'Owl',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-anemone',
#      'name': 'Anemone',
#      'class': 'Aquatic',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-trump',
#      'name': 'Trump',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-granmas-fan',
#      'name': "Granma's Fan",
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '392330',
#    'name': 'V Aqua Bird',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 0,
#    'image': 'https://assets.axieinfinity.com/axies/392330/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-raven',
#      'name': 'Raven',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-teal-shell',
#      'name': 'Teal Shell',
#      'class': 'Aquatic',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-the-last-one',
#      'name': 'The Last One',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '1589013',
#    'name': 'AROMA BAIT',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 2,
#    'image': 'https://assets.axieinfinity.com/axies/1589013/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-curly',
#      'name': 'Curly',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-raven',
#      'name': 'Raven',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-hungry-bird',
#      'name': 'Hungry Bird',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-eggshell',
#      'name': 'Eggshell',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-feather-fan',
#      'name': 'Feather Fan',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '6828208',
#    'name': 'Birdy',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 0,
#    'image': 'https://assets.axieinfinity.com/axies/6828208/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-robin',
#      'name': 'Robin',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-pink-cheek',
#      'name': 'Pink Cheek',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-sponge',
#      'name': 'Sponge',
#      'class': 'Aquatic',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-doubletalk',
#      'name': 'Doubletalk',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-eggshell',
#      'name': 'Eggshell',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-post-fight',
#      'name': 'Post Fight',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '3095609',
#    'name': '0',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 0,
#    'image': 'https://assets.axieinfinity.com/axies/3095609/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-blue-moon',
#      'name': 'Blue Moon',
#      'class': 'Aquatic',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-little-owl',
#      'name': 'Little Owl',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-teal-shell',
#      'name': 'Teal Shell',
#      'class': 'Aquatic',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-post-fight',
#      'name': 'Post Fight',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '2642133',
#    'name': 'Axie #2642133',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 0,
#    'image': 'https://assets.axieinfinity.com/axies/2642133/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-robin',
#      'name': 'Robin',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-pink-cheek',
#      'name': 'Pink Cheek',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-cupid',
#      'name': 'Cupid',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-risky-fish',
#      'name': 'Risky Fish',
#      'class': 'Aquatic',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-eggshell',
#      'name': 'Eggshell',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-the-last-one',
#      'name': 'The Last One',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '2069829',
#    'name': 'Axie #2069829',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 2,
#    'image': 'https://assets.axieinfinity.com/axies/2069829/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-early-bird',
#      'name': 'Early Bird',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-cupid',
#      'name': 'Cupid',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-doubletalk',
#      'name': 'Doubletalk',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-oranda',
#      'name': 'Oranda',
#      'class': 'Aquatic',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-the-last-one',
#      'name': 'The Last One',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '1363509',
#    'name': 'Axie #1363509',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 3,
#    'image': 'https://assets.axieinfinity.com/axies/1363509/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-cupid',
#      'name': 'Cupid',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-kestrel',
#      'name': 'Kestrel',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-granmas-fan',
#      'name': "Granma's Fan",
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '531502',
#    'name': 'Axie #531502',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 4,
#    'image': 'https://assets.axieinfinity.com/axies/531502/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-cupid',
#      'name': 'Cupid',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-kestrel',
#      'name': 'Kestrel',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-granmas-fan',
#      'name': "Granma's Fan",
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '4382825',
#    'name': 'Super Super Low ID#',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 2,
#    'image': 'https://assets.axieinfinity.com/axies/4382825/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-mavis',
#      'name': 'Mavis',
#      'class': 'Bird',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-owl',
#      'name': 'Owl',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-raven',
#      'name': 'Raven',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-hungry-bird',
#      'name': 'Hungry Bird',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-oranda',
#      'name': 'Oranda',
#      'class': 'Aquatic',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-the-last-one',
#      'name': 'The Last One',
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'},
#   {'id': '3466422',
#    'name': 'Birdie Buddy!',
#    'stage': 4,
#    'class': 'Bird',
#    'breedCount': 0,
#    'image': 'https://assets.axieinfinity.com/axies/3466422/axie/axie-full-transparent.png',
#    'title': '',
#    'battleInfo': {'banned': False, '__typename': 'AxieBattleInfo'},
#    'auction': {'currentPrice': '20000000000000000',
#     'currentPriceUSD': '50.23',
#     '__typename': 'Auction'},
#    'parts': [{'id': 'eyes-telescope',
#      'name': 'Telescope',
#      'class': 'Aquatic',
#      'type': 'Eyes',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'ears-peace-maker',
#      'name': 'Peace Maker',
#      'class': 'Bird',
#      'type': 'Ears',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'back-pigeon-post',
#      'name': 'Pigeon Post',
#      'class': 'Bird',
#      'type': 'Back',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'mouth-hungry-bird',
#      'name': 'Hungry Bird',
#      'class': 'Bird',
#      'type': 'Mouth',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'horn-trump',
#      'name': 'Trump',
#      'class': 'Bird',
#      'type': 'Horn',
#      'specialGenes': None,
#      '__typename': 'AxiePart'},
#     {'id': 'tail-granmas-fan',
#      'name': "Granma's Fan",
#      'class': 'Bird',
#      'type': 'Tail',
#      'specialGenes': None,
#      '__typename': 'AxiePart'}],
#    '__typename': 'Axie'}],
#  '__typename': 'Axies'}

# %%
def get_optimal_deck(addr):
    url = f"https://tracking.skymavis.com/battle-history?type=pvp&player_id={addr}"
    response = requests.request("GET", url)
    battles = json.loads(response.text)["battles"]

    deck_dict = {}
    most_freq = 0
    for battle in battles:
        team1 = tuple(sorted(battle['first_team_fighters']))
        if team1 in deck_dict:
            deck_dict[team1] += 1
        else:
            deck_dict[team1] = 1

        if most_freq < deck_dict[team1]:
            most_freq = deck_dict[team1]
            opt_deck = team1

        team2 = tuple(sorted(battle['second_team_fighters']))
        if team2 in deck_dict:
            deck_dict[team2] += 1
        else:
            deck_dict[team2] = 1

        if most_freq < deck_dict[team2]:
            most_freq = deck_dict[team2]
            opt_deck = team2
    return opt_deck, most_freq

# %%
def get_axie_for_sale(id):
    url = f'https://api.axie.technology/getaxies/{id}'
    response = requests.request("GET", url)
    axie = json.loads(response.text)
    url_parts =''.join([f'&part={part["id"]}' for part in axie['parts'] if not (part["id"].split('-')[0] in ['ears', 'eyes'])])
    del axie["stats"]['__typename']
    sorted_dict = sorted(axie["stats"].items(), key = lambda item: item[1])
    url_stats = ''
    for stat in sorted_dict[-1:]:
        url_stats += f'&{stat[0]}={stat[1]}&{stat[0]}=61'
    return f'https://marketplace.axieinfinity.com/axie/?class={axie["sireClass"]}{url_parts}{url_stats}&auctionTypes=Sale'

get_axie_for_sale(10825538)
# Out:
# 'https://marketplace.axieinfinity.com/axie/?class=Mech&part=back-hero&part=mouth-nut-cracker&part=horn-arco&part=tail-nut-cracker&speed=49&speed=61&auctionTypes=Sale'

# %%
payload = {
    "operationName": "NewEthExchangeRate",
    "query": "query NewEthExchangeRate {\n  exchangeRate {\n    eth {\n      usd\n      __typename\n    }\n    __typename\n  }\n}\n",
    "variables": {}
}
r = requests.post("https://graphql-gateway.axieinfinity.com/graphql", json=payload)
ethusd = json.loads(r.text)['data']['exchangeRate']['eth']['usd']
ethusd
# Out:
# 2504.29

# %% [markdown]
# ### Track similar deck w/ ids

# %%
ids = [url.split('/')[-2] for url in
'''
https://marketplace.axieinfinity.com/axie/10878361/
https://marketplace.axieinfinity.com/axie/10878072/
'''.split('\n')[1:-1]]

def track_by_ids(ids):
    total_price = 0
    total_query = ''
    for i, id in enumerate(ids):
        query = get_axie_for_sale(id)
        ac = AxieCriterion(query)
        data = ac.marketplace()
        if len(data['results']) != 0:
            results = data['results'][0]

            price = round(float(results["auction"]["currentPriceUSD"]) / ethusd, 3)
            if i != 0:
                print(' +', price, "ETH", end='')
            else:
                print(price, "ETH", end='')
        else:
            query = 'n/a'
            price = 0

        total_query += query + '\n'
        total_price += price
    print(f' = {total_price:.3f} ETH')
    print(total_query)
track_by_ids(ids)
# Out:
# 0.042 ETH + 0.042 ETH = 0.084 ETH
# https://marketplace.axieinfinity.com/axie/?class=Bug&part=back-sandal&part=mouth-pincer&part=horn-parasite&part=tail-fish-snack&morale=57&morale=61&auctionTypes=Sale
# https://marketplace.axieinfinity.com/axie/?class=Bug&part=back-scarab&part=mouth-pincer&part=horn-parasite&part=tail-fish-snack&morale=57&morale=61&auctionTypes=Sale

# %% [markdown]
# ### Track deck w/ queries

# %%
queries = '''
 https://marketplace.axieinfinity.com/axie/?class=Dusk&part=back-green-thorns&part=mouth-tiny-turtle&part=horn-kestrel&part=tail-hot-butt&hp=53&hp=61&speed=50&speed=61&auctionTypes=Sale
https://marketplace.axieinfinity.com/axie/?class=Plant&part=back-watering-can&part=mouth-serious&part=horn-cactus&part=tail-hot-butt&hp=61&hp=61&auctionTypes=Sale
https://marketplace.axieinfinity.com/axie/?class=Bug&part=back-scarab&part=mouth-pincer&part=horn-parasite&part=tail-fish-snack&morale=55&morale=61&auctionTypes=Sale
'''.split()

def track_by_queries(queries):
    total_price = 0
    total_query = ''
    for i, query in enumerate(queries):
        ac = AxieCriterion(query)
        data = ac.marketplace()
        if len(data['results']) != 0:
            results = data['results'][0]

            price = round(float(results["auction"]["currentPriceUSD"]) / ethusd, 3)
            if i != 0:
                print(' +', price, "ETH", end='')
            else:
                print(price, "ETH", end='')
        else:
            query = 'n/a'
            price = 0

        total_query += query + '\n'
        total_price += price
    print(f' = {total_price:.3f} ETH')
    print(total_query)
track_by_queries(queries)
# Out:
# 0.046 ETH + 0.034 ETH + 0.041 ETH = 0.121 ETH
# https://marketplace.axieinfinity.com/axie/?class=Dusk&part=back-green-thorns&part=mouth-tiny-turtle&part=horn-kestrel&part=tail-hot-butt&hp=53&hp=61&speed=50&speed=61&auctionTypes=Sale
# https://marketplace.axieinfinity.com/axie/?class=Plant&part=back-watering-can&part=mouth-serious&part=horn-cactus&part=tail-hot-butt&hp=61&hp=61&auctionTypes=Sale
# https://marketplace.axieinfinity.com/axie/?class=Bug&part=back-scarab&part=mouth-pincer&part=horn-parasite&part=tail-fish-snack&morale=55&morale=61&auctionTypes=Sale

# %%
response = requests.request("GET", 'https://axie.zone/leaderboard')
html = response.text
trs = bs(html).find_all('tr')
leaderboard = []

for tr in trs[1:20]:
    tds = tr.find_all('td')
    rank = int(tds[0].text[1:])
    ron_addr = tds[1].find("a")["href"].split('=')[-1]
    name = tds[1].text
    axies = get_optimal_deck(ron_addr)[0]
    leaderboard.append([rank, ron_addr, name, axies[0], axies[1], axies[2]])
    print(rank, name)
    track_by_ids(axies)
    
df = pd.DataFrame(leaderboard, columns=['rank', 'ron_addr', 'name', 'axie#1', 'axie#2', 'axie#3'])
df
# Out:
# 1 Mapo Tofu | fb.gg/tofuknightsPH
# 0.169 ETH + 0.125 ETH + 0.145 ETH = 0.439 ETH
# https://marketplace.axieinfinity.com/axie/?class=Bird&part=back-balloon&part=mouth-peace-maker&part=horn-arco&part=tail-hare&speed=57&speed=61&auctionTypes=Sale
# https://marketplace.axieinfinity.com/axie/?class=Plant&part=back
61&auctionTypes=Sale
# https://marketplace.axieinfinity.com/axie/?class=Aquatic&part=back-scarab&part=mouth-risky-fish&part=horn-arco&part=tail-nimo&speed=52&speed=61&auctionTypes=Sale
#
# 19 imcute | HA
# 0.062 ETH + 0.051 ETH + 0.1 ETH = 0.213 ETH
# https://marketplace.axieinfinity.com/axie/?class=Aquatic&part=back-blue-moon&part=mouth-piranha&part=horn-oranda&part=tail-shrimp&speed=57&speed=61&auctionTypes=Sale
# https://marketplace.axieinfinity.com/axie/?class=Mech&part=back-hero&part=mouth-goda&part=horn-arco&part=tail-hare&speed=49&speed=61&auctionTypes=Sale
# https://marketplace.axieinfinity.com/axie/?class=Plant&part=back-bidens&part=mouth-herbivore&part=horn-beech&part=tail-cattail&hp=61&hp=61&auctionTypes=Sale
#     rank                                    ron_addr  \
# 0      1  0x53e06a192466cd29b1809a4c1eca3f746bd08d65
# 1      2  0xeb68215f550be82c0d7be10c38ff69c2d30cdb56
# 2      3  0x4d9f7c8e438943ba2cccd3a24d91f7cf9b5a7cc6
# 3      4  0xa261cdf0942e79b1ca92b02e6ba166ae4798538b
# 4      5  0x47c73a4e7a93a4797b804f048fb983d6d492e1b8
# 5      6  0x2243205cbe1af6e8f40a64a3f6c028e92214c9bc
# 6      7  0x07f539753f239dded678ba137a7cc20118130d84
# 7      8  0x6e9664764dff76d25ffa312c6a0eb534e5c80215
# 8      9  0x3a492379eb13dff01d90ec1a7ae696f8955aa714
# 9     10  0x936064823bd7fe3c86b63629083b05ae9e13e2dd
# 10    11  0x02568d053eac680f786dde00c690404ace9686d5
# 11    12  0xbc57d808e9876b0ff2f0baaf41ae5345fe18b6bc
# 12    13  0x9037b5a75338c8d35ebfb13a31fe7bf5b2a17ec2
# 13    14  0x12509afe6b39d7ea2d0d47887de3527f32eae2f2
# 14    15  0x11aa9d50324be9550acd751b8b3364f4c23f7117
# 15    16  0xcffd81f11ee80bee1bea5174de9c05c401d15ec7
# 16    17  0xcae181cc4dae7ad39aa71500f16319f56123c168
# 17    18  0x7b4fd408607e091433c87d15e4450297bf766ff5
# 18    19  0x442634777d06e052b32506e0582dbaedb9b15ccd
#
#                                 name    axie#1    axie#2    axie#3
# 0    Mapo Tofu | fb.gg/tofuknightsPH   9689597  10352131  10521508
# 1                           TUP Baam   8791724   9653888  10377089
# 2                           Spriggan    369570    673113   6143639
# 3         fb.gg/KouseiPotatoSquad :P  10153722  10175055  10612886
# 4              Dave | The LNCN Mafia   4696326   8737652  10129601
# 5        BIG CHIEF | USA + PH | Chan   2657205   6881219   9704497
# 6                  PemPem | Ancient8   9818997  10564486  10580236
# 7                           Roblolux   6536128   9351632  10463066
# 8                   xSkyyy | Axie.gg   6209490   9878890  10499324
# 9                         Russ | POG   9356633  10445186  10596343
# 10     Youtube | de-hi games | Lev0x   9334163   9528109  10426449
# 11               KYDA | Sampi | DH52   6270426   7268272   9401117
# 12            Kb | MAS | fb:@AXIEMAS   9826421   9880948   9986014
# 13               Kneel | POG | MTTM    9325086  10721365  10727506
# 14     ADD ME ON FB: JAYJAY BATIFORA   1079544   3803172   3804846
# 15                         Long Văn    9001538   9784297  10416771
# 16  louietatit | fb.gg/tofuknightsPH   9401787   9739521  10414194
# 17                            Zaraki   9744564   9971624  10560667
# 18                       imcute | HA   8700362  10632993  10651691
